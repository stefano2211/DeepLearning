# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
import math
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
# Out:
# C:\Users\Stefano.DESKTOP-TULLGHQ\AppData\Local\Temp\ipykernel_10316\2766741643.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
# WARNING:tensorflow:From c:\Users\Stefano.DESKTOP-TULLGHQ\Documents\GitHub\DeepLearning\.venv\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
dataframe = pd.read_csv("../dataset/AirPassengers.csv", usecols=[1], engine='python')
dataset = dataframe.values
dataset = dataset.astype('float')

# %%
def create_dataset(dataset, look_back=1):
    dataX, dataY = [], []
    for i in range(len(dataset)-look_back-1):
        a = dataset[i:(i+look_back), 0]
        dataX.append(a)
        dataY.append(dataset[i + look_back, 0])
    return np.array(dataX), np.array(dataY)

# %%
scaler = MinMaxScaler(feature_range=(0,1))
dataset = scaler.fit_transform(dataset)

# %%
train_size = int(len(dataset) * 0.67)
test_size =  len(dataset) - train_size
train , test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]

# %%
look_back = 3
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test,look_back)

# %%
trainX = np.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
testX = np.reshape(testX, (testX.shape[0], 1, testX.shape[1]))

# %%
model = Sequential()
model.add(LSTM(4, input_shape=(1, look_back)))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(trainX,trainY,epochs=100,batch_size=1,verbose=2)
# Out:
# WARNING:tensorflow:From c:\Users\Stefano.DESKTOP-TULLGHQ\Documents\GitHub\DeepLearning\.venv\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From c:\Users\Stefano.DESKTOP-TULLGHQ\Documents\GitHub\DeepLearning\.venv\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Epoch 1/100
# WARNING:tensorflow:From c:\Users\Stefano.DESKTOP-TULLGHQ\Documents\GitHub\DeepLearning\.venv\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 92/92 - 1s - loss: 0.0415 - 1s/epoch - 12ms/step
# Epoch 2/100
# 92/92 - 0s - loss: 0.0178 - 89ms/epoch - 971us/step
# Epoch 3/100
# 92/92 - 0s - loss: 0.0116 - 78ms/epoch - 851us/step
# Epoch 4/100
# 92/92 - 0s - loss: 0.0100 - 79ms/epoch - 855us/step
# Epoch 5/100
# 92/92 - 0s - loss: 0.0089 - 80ms/epoch - 870us/step
# Epoch 6/100
# 92/92 - 0s - loss: 0.0077 - 80ms/epoch - 866us/step
# Epoch 7/100
# 92/92 - 0s - loss: 0.0067 - 78ms/epoch - 851us/step
# Epoch 8/100
# 92/92 - 0s - loss: 0.0058 - 80ms/epoch - 871us/step
# Epoch 9/100
# 92/92 - 0s - loss: 0.0051 - 79ms/epoch - 864us/step
# Epoch 10/100
# 92/92 - 0s - loss: 0.0046 - 80ms/epoch - 865us/step
# Epoch 11/100
# 92/92 - 0s - loss: 0.0041 - 78ms/epoch - 848us/step
# Epoch 12/100
# 92/92 - 0s - loss: 0.0038 - 79ms/epoch - 854us/step
# Epoch 13/100
# 92/92 - 0s - loss: 0.0036 - 78ms/epoch - 852us/step
# Epoch 14/100
# 92/92 - 0s - loss: 0.0034 - 66ms/epoch - 722us/step
# Epoch 15/100
# 92/92 - 0s - loss: 0.0033 - 99ms/epoch - 1ms/step
# Epoch 16/100
# 92/92 - 0s - loss: 0.0033 - 82ms/epoch - 895us/step
# Epoch 17/100
# 92/92 - 0s - loss: 0.0033 - 69ms/epoch - 746us/step
# Epoch 18/100
# 92/92 - 0s - loss: 0.0032 - 91ms/epoch - 987us/step
# Epoch 19/100
# 92/92 - 0s - loss: 0.0032 - 75ms/epoch - 813us/step
# Epoch 20/100
# 92/92 - 0s - loss: 0.0031 - 82ms/epoch - 895us/step
# Epoch 21/100
# 92/92 - 0s - loss: 0.0030 - 81ms/epoch - 878us/step
# Epoch 22/100
# 92/92 - 0s - loss: 0.0031 - 71ms/epoch - 775us/step
# Epoch 23/100
# 92/92 - 0s - loss: 0.0032 - 81ms/epoch - 882us/step
# Epoch 24/100
# 92/92 - 0s - loss: 0.0030 - 83ms/epoch - 904us/step
# Epoch 25/100
# 92/92 - 0s - loss: 0.0030 - 67ms/epoch - 726us/step
# Epoch 26/100
# 92/92 - 0s - loss: 0.0031 - 70ms/epoch - 760us/step
# Epoch 27/100
# 92/92 - 0s - loss: 0.0030 - 81ms/epoch - 880us/step
# Epoch 28/100
# 92/92 - 0s - loss: 0.0030 - 83ms/epoch - 898us/step
# Epoch 29/100
# 92/92 - 0s - loss: 0.0029 - 69ms/epoch - 746us/step
# Epoch 30/100
# 92/92 - 0s - loss: 0.0029 - 84ms/epoch - 915us/step
# Epoch 31/100
# 92/92 - 0s - loss: 0.0030 - 81ms/epoch - 882us/step
# Epoch 32/100
# 92/92 - 0s - loss: 0.0029 - 82ms/epoch - 896us/step
# Epoch 33/100
# 92/92 - 0s - loss: 0.0029 - 69ms/epoch - 748us/step
# Epoch 34/100
# 92/92 - 0s - loss: 0.0029 - 67ms/epoch - 723us/step
# Epoch 35/100
# 92/92 - 0s - loss: 0.0028 - 83ms/epoch - 906us/step
# Epoch 36/100
# 92/92 - 0s - loss: 0.0029 - 82ms/epoch - 895us/step
# Epoch 37/100
# 92/92 - 0s - loss: 0.0028 - 68ms/epoch - 734us/step
# Epoch 38/100
# 92/92 - 0s - loss: 0.0028 - 67ms/epoch - 726us/step
# Epoch 39/100
# 92/92 - 0s - loss: 0.0028 - 84ms/epoch - 915us/step
# Epoch 40/100
# 92/92 - 0s - loss: 0.0028 - 82ms/epoch - 895us/step
# Epoch 41/100
# 92/92 - 0s - loss: 0.0027 - 69ms/epoch - 751us/step
# Epoch 42/100
# 92/92 - 0s - loss: 0.0028 - 92ms/epoch - 997us/step
# Epoch 43/100
# 92/92 - 0s - loss: 0.0027 - 79ms/epoch - 857us/step
# Epoch 44/100
# 92/92 - 0s - loss: 0.0028 - 76ms/epoch - 826us/step
# Epoch 45/100
# 92/92 - 0s - loss: 0.0027 - 82ms/epoch - 895us/step
# Epoch 46/100
# 92/92 - 0s - loss: 0.0027 - 67ms/epoch - 725us/step
# Epoch 47/100
# 92/92 - 0s - loss: 0.0026 - 85ms/epoch - 929us/step
# Epoch 48/100
# 92/92 - 0s - loss: 0.0026 - 85ms/epoch - 920us/step
# Epoch 49/100
# 92/92 - 0s - loss: 0.0026 - 82ms/epoch - 888us/step
# Epoch 50/100
# 92/92 - 0s - loss: 0.0026 - 83ms/epoch - 907us/step
# Epoch 51/100
# 92/92 - 0s - loss: 0.0026 - 64ms/epoch - 700us/step
# Epoch 52/100
# 92/92 - 0s - loss: 0.0026 - 82ms/epoch - 896us/step
# Epoch 53/100
# 92/92 - 0s - loss: 0.0026 - 85ms/epoch - 929us/step
# Epoch 54/100
# 92/92 - 0s - loss: 0.0026 - 81ms/epoch - 882us/step
# Epoch 55/100
# 92/92 - 0s - loss: 0.0025 - 67ms/epoch - 725us/step
# Epoch 56/100
# 92/92 - 0s - loss: 0.0025 - 82ms/epoch - 895us/step
# Epoch 57/100
# 92/92 - 0s - loss: 0.0025 - 84ms/epoch - 915us/step
# Epoch 58/100
# 92/92 - 0s - loss: 0.0025 - 86ms/epoch - 936us/step
# Epoch 59/100
# 92/92 - 0s - loss: 0.0025 - 81ms/epoch - 876us/step
# Epoch 60/100
# 92/92 - 0s - loss: 0.0024 - 82ms/epoch - 894us/step
# Epoch 61/100
# 92/92 - 0s - loss: 0.0025 - 69ms/epoch - 745us/step
# Epoch 62/100
# 92/92 - 0s - loss: 0.0025 - 84ms/epoch - 916us/step
# Epoch 63/100
# 92/92 - 0s - loss: 0.0024 - 81ms/epoch - 886us/step
# Epoch 64/100
# 92/92 - 0s - loss: 0.0024 - 83ms/epoch - 905us/step
# Epoch 65/100
# 92/92 - 0s - loss: 0.0024 - 82ms/epoch - 886us/step
# Epoch 66/100
# 92/92 - 0s - loss: 0.0023 - 69ms/epoch - 754us/step
# Epoch 67/100
# 92/92 - 0s - loss: 0.0024 - 81ms/epoch - 885us/step
# Epoch 68/100
# 92/92 - 0s - loss: 0.0024 - 82ms/epoch - 895us/step
# Epoch 69/100
# 92/92 - 0s - loss: 0.0023 - 68ms/epoch - 744us/step
# Epoch 70/100
# 92/92 - 0s - loss: 0.0023 - 84ms/epoch - 917us/step
# Epoch 71/100
# 92/92 - 0s - loss: 0.0023 - 81ms/epoch - 884us/step
# Epoch 72/100
# 92/92 - 0s - loss: 0.0023 - 83ms/epoch - 905us/step
# Epoch 73/100
# 92/92 - 0s - loss: 0.0024 - 67ms/epoch - 725us/step
# Epoch 74/100
# 92/92 - 0s - loss: 0.0024 - 85ms/epoch - 925us/step
# Epoch 75/100
# 92/92 - 0s - loss: 0.0023 - 82ms/epoch - 887us/step
# Epoch 76/100
# 92/92 - 0s - loss: 0.0023 - 82ms/epoch - 895us/step
# Epoch 77/100
# 92/92 - 0s - loss: 0.0023 - 84ms/epoch - 914us/step
# Epoch 78/100
# 92/92 - 0s - loss: 0.0023 - 69ms/epoch - 745us/step
# Epoch 79/100
# 92/92 - 0s - loss: 0.0023 - 82ms/epoch - 886us/step
# Epoch 80/100
# 92/92 - 0s - loss: 0.0022 - 82ms/epoch - 896us/step
# Epoch 81/100
# 92/92 - 0s - loss: 0.0023 - 84ms/epoch - 914us/step
# Epoch 82/100
# 92/92 - 0s - loss: 0.0022 - 69ms/epoch - 745us/step
# Epoch 83/100
# 92/92 - 0s - loss: 0.0021 - 81ms/epoch - 885us/step
# Epoch 84/100
# 92/92 - 0s - loss: 0.0022 - 82ms/epoch - 895us/step
# Epoch 85/100
# 92/92 - 0s - loss: 0.0021 - 83ms/epoch - 905us/step
# Epoch 86/100
# 92/92 - 0s - loss: 0.0021 - 84ms/epoch - 916us/step
# Epoch 87/100
# 92/92 - 0s - loss: 0.0022 - 67ms/epoch - 725us/step
# Epoch 88/100
# 92/92 - 0s - loss: 0.0022 - 67ms/epoch - 725us/step
# Epoch 89/100
# 92/92 - 0s - loss: 0.0022 - 85ms/epoch - 926us/step
# Epoch 90/100
# 92/92 - 0s - loss: 0.0021 - 84ms/epoch - 916us/step
# Epoch 91/100
# 92/92 - 0s - loss: 0.0021 - 65ms/epoch - 703us/step
# Epoch 92/100
# 92/92 - 0s - loss: 0.0021 - 67ms/epoch - 726us/step
# Epoch 93/100
# 92/92 - 0s - loss: 0.0021 - 85ms/epoch - 925us/step
# Epoch 94/100
# 92/92 - 0s - loss: 0.0021 - 83ms/epoch - 905us/step
# Epoch 95/100
# 92/92 - 0s - loss: 0.0021 - 65ms/epoch - 705us/step
# Epoch 96/100
# 92/92 - 0s - loss: 0.0021 - 82ms/epoch - 895us/step
# Epoch 97/100
# 92/92 - 0s - loss: 0.0021 - 84ms/epoch - 915us/step
# Epoch 98/100
# 92/92 - 0s - loss: 0.0020 - 67ms/epoch - 725us/step
# Epoch 99/100
# 92/92 - 0s - loss: 0.0020 - 68ms/epoch - 735us/step
# Epoch 100/100
# 92/92 - 0s - loss: 0.0021 - 83ms/epoch - 905us/step

# %%
trainPredict = model.predict(trainX)
testPredict =model.predict(testX)

trainPredict = scaler.inverse_transform(trainPredict)
trainY =  scaler.inverse_transform([trainY])
testPredict = scaler.inverse_transform(testPredict)
testY =  scaler.inverse_transform([testY])

trainScore = math.sqrt(mean_squared_error(trainY[0], trainPredict[:, 0]))
print(trainScore)
testScore = math.sqrt(mean_squared_error(testY[0], testPredict[:, 0]))
print(trainScore)


trainPredictPlot = np.empty_like(dataset)
trainPredictPlot[ : , :] = np.nan
trainPredictPlot[look_back:len(trainPredict)+ look_back, :] = trainPredict

testPredictPlot = np.empty_like(dataset)
testPredictPlot[ : , :] = np.nan
testPredictPlot[len(trainPredict) + (look_back*2)+1:len(dataset)-1, :] = testPredict

plt.figure(figsize=(12,8))
plt.plot(scaler.inverse_transform(dataset))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()
# Out:
# 3/3 [==============================] - 0s 1ms/step
# 2/2 [==============================] - 0s 2ms/step
# 23.051746347543478
# 23.051746347543478
